# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("raw_data/full_data.csv")
df
# Out:
#             date     location  new_cases  new_deaths  total_cases  \
# 0     2019-12-31  Afghanistan          0           0            0
# 1     2020-01-01  Afghanistan          0           0            0
# 2     2020-01-02  Afghanistan          0           0            0
# 3     2020-01-03  Afghanistan          0           0            0
# 4     2020-01-04  Afghanistan          0           0            0
# ...          ...          ...        ...         ...          ...
# 6631  2020-03-24       Zambia          0           0            3
# 6632  2020-03-21     Zimbabwe          1           0            1
# 6633  2020-03-22     Zimbabwe          1           0            2
# 6634  2020-03-23     Zimbabwe          0           0            2
# 6635  2020-03-24     Zimbabwe          0           1            2
#
#       total_deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 6631             0
# 6632             0
# 6633             0
# 6634             0
# 6635             1
#
# [6636 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6636 entries, 0 to 6635
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          6636 non-null   object
#  1   location      6636 non-null   object
#  2   new_cases     6636 non-null   int64
#  3   new_deaths    6636 non-null   int64
#  4   total_cases   6636 non-null   int64
#  5   total_deaths  6636 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 311.2+ KB

# %%
df['date'] =  pd.to_datetime(df['date'], format='%d%b%Y:%H:%M')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-25af51cbb7ca> in <module>
# ----> 1 df['date'] =  pd.to_datetime(df['date'], format='%d%b%Y:%H:%M:%S.%f')
#       2 df
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     722                 result = result.tz_localize(tz)
#     723     elif isinstance(arg, ABCSeries):
# --> 724         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     725         if not cache_array.empty:
#     726             result = arg.map(cache_array)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     150         unique_dates = unique(arg)
#     151         if len(unique_dates) < len(arg):
# --> 152             cache_dates = convert_listlike(unique_dates, format)
#     153             cache_array = Series(cache_dates, index=unique_dates)
#     154     return cache_array
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     434             except (ValueError, TypeError):
# --> 435                 raise e
#     436
#     437     if result is None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     398                 try:
#     399                     result, timezones = array_strptime(
# --> 400                         arg, format, exact=exact, errors=errors
#     401                     )
#     402                     if "%Z" in format or "%z" in format:
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2019-12-31' does not match format '%d%b%Y:%H:%M:%S.%f' (match)
